# %%
import pandas as pd

# %%
df = pd.read_csv('AB_NYC_2019.csv')
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
min_thersold = df.price.quantile(0.01)
min_thersold
# Out:
# 30.0

# %%
max_thersold = df.price.quantile(0.999)
max_thersold
# Out:
# 3000.0

# %%
df[df.price<min_thersold]
# Out:
#              id                                             name    host_id  \
# 957      375249                  Enjoy Staten Island Hospitality    1887999
# 2675    1428154              Central, Peaceful Semi-Private Room    5912572
# 2860    1620248    Large furnished 2 bedrooms- - 30 days Minimum    2196224
# 3020    1767037               Small Cozy Room Wifi & AC near JFK    9284163
# 3918    2431607                    Bright, Airy Room Share for 2    4973668
# ...         ...                                              ...        ...
# 48486  36280646                     Cable and wfi, L/G included.  272872092
# 48647  36354776    Cozy bedroom in diverse neighborhood near JFK  273393150
# 48832  36450814                         FLATBUSH HANG OUT AND GO  267223765
# 48867  36473044  The place you were dreaming for.(only for guys)  261338177
# 48868  36473253                     Heaven for you(only for guy)  261338177
#
# ...

# %%
df2 = df[(df.price>min_thersold) & (df.price<max_thersold)]
df2
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df2 = df[(df.price>min_thersold) & (df.price<max_thersold)]
df2.shape
# Out:
# (48183, 16)

# %%
df2.sample(5)
# Out:
#              id                                               name    host_id  \
# 23863  19261252        Luxurious Designer brownstone with backyard    5453550
# 38999  30469490   Quick walk to Metro, Cleaning, & Great roommates  154981576
# 26054  20788473                                        Basin Homes   46253884
# 1463     655472                Lovely 2-room Studio in Crown Hghts     326329
# 45105  34537321  Pleasant & comfortable furnished studio apartment   83786650
#
#                host_name neighbourhood_group    neighbourhood  latitude  \
# 23863  Christine & James            Brooklyn     Clinton Hill  40.69556
# 38999     Bedly Bushwick            Brooklyn         Bushwick  40.70029
# 26054             Audlyn            Brooklyn         Canarsie  40.62944
# 1463                Nick            Brooklyn    Crown Heights  40.67574
# 45105             Bridge           Manhattan  Upper East Side  40.75972
#
# ...

# %%
df2.price.describe()
# Out:
# count    48183.000000
# mean       148.772036
# std        153.594795
# min         31.000000
# 25%         70.000000
# 50%        110.000000
# 75%        179.000000
# max       2999.000000
# Name: price, dtype: float64
